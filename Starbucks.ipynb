# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

def zerolistmaker(n):
    listofzeros = [0] * n
    return listofzeros

zeroes = zerolistmaker(len(totalList))

# %% [markdown]
# ### Starbucks:

# %%
totalList = [521, 517, 519, 514, 518, 524, 532, 533, 534, 540, 539, 544, 531, 530]

days = list(range(0, len(totalList)))

incomesList = [5, 1, 3, -2, 2, 9, 16, 17, 18, 24, 23, 28, 15, 14]

numberOfActions = [10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10]

# %%
plt.title('Total sum')
sns.pointplot(days, totalList , color="blue")

# %%
plt.title('Income')
sns.pointplot(days, incomesList , color="blue")
sns.pointplot(days, zeroes, markers="")

# %%
trueIncomesList = list()

for i in range(0, len(totalList)):
    trueIncomesList.append(incomesList[i] / totalList[i])
    
print(trueIncomesList)
# Out:
# [0.009596928982725527, 0.0019342359767891683, 0.005780346820809248, -0.0038910505836575876, 0.003861003861003861, 0.01717557251908397, 0.03007518796992481, 0.03189493433395872, 0.033707865168539325, 0.044444444444444446, 0.04267161410018553, 0.051470588235294115, 0.02824858757062147, 0.026415094339622643]

# %%
plt.title('True income')
sns.pointplot(days, trueIncomesList , color="blue")
sns.pointplot(days, zeroes, markers="")
