# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

def zerolistmaker(n):
    listofzeros = [0] * n
    return listofzeros

zeroes = zerolistmaker(len(totalList))

# %% [markdown]
# ### Mastercard:

# %%
totalList = [203, 405, 408, 405, 406, 409, 408, 404, 812, 817, 820, 818, 821]

days = list(range(0, len(totalList)))

incomesList = [-6, -2, 1, -2, -1, 2, 1, -2, -2, 3, 6, 4, 7]

numberOfActions = [1, 2, 2, 2, 2, 2, 2, 2, 4, 4, 4, 4, 4]

# %%
plt.title('Total sum')
sns.pointplot(days, totalList , color="blue")

# %%
plt.title('Income')
sns.pointplot(days, incomesList , color="blue")
sns.pointplot(days, zeroes, markers="")

# %%
trueIncomesList = list()

for i in range(0, len(totalList)):
    trueIncomesList.append(incomesList[i] / totalList[i])
    
print(trueIncomesList)
# Out:
# [-0.029556650246305417, -0.0049382716049382715, 0.0024509803921568627, -0.0049382716049382715, -0.0024630541871921183, 0.004889975550122249, 0.0024509803921568627, -0.0049504950495049506, -0.0024630541871921183, 0.0036719706242350062, 0.007317073170731708, 0.004889975550122249, 0.008526187576126675]

# %%
plt.title('True income')
sns.pointplot(days, trueIncomesList , color="blue")
sns.pointplot(days, zeroes, markers="")
